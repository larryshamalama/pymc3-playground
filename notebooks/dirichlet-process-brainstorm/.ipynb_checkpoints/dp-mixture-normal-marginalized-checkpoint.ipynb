# %%
import sys
sys.path.insert(0, "../../../pymc")

import pymc as pm
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../../data/old_faithful.tsv", sep="\t")
data = data["eruptions"].values
data = (data - data.mean())/data.std()

_ = plt.hist(data, bins=30)

# %%
K = 30

# %%
with pm.Model():
    alpha = pm.Gamma("alpha", 1., 1.)
    sbw = pm.StickBreakingWeights("sbw", alpha, K=K)
    
    µ = pm.Normal("µ", 0., 5., shape=(K+1))
    σ = pm.Gamma("σ", 1., 1., shape=(K+1))
    λ = pm.Uniform("λ", 0., 5., shape=(K+1))
    
    mix = pm.Mixture(
        "mix",
        w=sbw,
        comp_dists=[pm.Normal.dist(mu=µ[j], sigma=σ[j]*λ[j]) for j in range(K+1)],
        observed=data,
    )
    
    trace = pm.sample(chains=1)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Sequential sampling (1 chains in 1 job)
# NUTS: [alpha, sbw, µ, σ, λ]
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='2000' class='' max='2000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [2000/2000 16:29<00:00 Sampling chain 0, 4 divergences]
#     </div>
# Sampling 1 chain for 1_000 tune and 1_000 draw iterations (1_000 + 1_000 draws total) took 990 seconds.
# There were 4 divergences after tuning. Increase `target_accept` or reparameterize.
# Only one chain was sampled, this makes it impossible to run some convergence checks

# %%
_ = pm.plot_trace(trace)
